# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import json
import requests

# %%
api_key = open('apikey.txt', 'r').read()

headers = {'Authorization':api_key}
url = 'https://api.lendingclub.com/api/investor/v1/loans/listing'
r = requests.get(url, headers=headers)

# %%
from bs4 import BeautifulSoup
html_doc = r.text
soup = BeautifulSoup(html_doc)
print(soup.prettify())
# Out:
# <html>
#  <body>
#   <p>
# ...

# %%
data = r.json()
myData = data['loans']

# %%
myData
# Out:
# [{'accNowDelinq': 0,
#   'accOpenPast24Mths': 1,
#   'acceptD': '2018-05-11T07:38:34.000-07:00',
#   'addrState': 'MI',
#   'addrZip': '488xx',
#   'allUtil': 64.6,
#   'annualInc': 57200.0,
#   'annualIncJoint': None,
#   'applicationType': 'INDIVIDUAL',
#   'avgCurBal': 3337,
#   'bcOpenToBuy': 3941,
#   'bcUtil': 71.2,
#   'chargeoffWithin12Mths': 0,
#   'collections12MthsExMed': 0,
#   'creditPullD': '2018-05-11T07:26:37.000-07:00',
#   'delinq2Yrs': 0,
#   'delinqAmnt': 0.0,
#   'desc': None,
#   'disbursementMethod': 'DIRECT_PAY',
#   'dti': 6.46,
#   'dtiJoint': None,
#   'earliestCrLine': '2003-06-10T17:00:00.000-07:00',
#   'empLength': 84,
#   'empTitle': 'Customer service',
#   'expD': '2018-06-12T10:00:00.000-07:00',
#   'expDefaultRate': 1.88,
#   'ficoRangeHigh': 674,
#   'ficoRangeLow': 670,
#   'fundedAmount': 3050.0,
#   'grade': 'A',
#   'homeOwnership': 'MORTGAGE',
#   'housingPayment': 1100.0,
#   'iLUtil': None,
#   'id': 133302955,
# ...

# %%
with open('current_list.txt', 'w') as outfile:
    json.dump(myData, outfile)

# %%
df_current= pd.read_json('current_list.txt')

# %%
df_current
# Out:
#    accNowDelinq  accOpenPast24Mths                        acceptD addrState  \
# 0             0                  1  2018-05-11T07:38:34.000-07:00        MI
# 1             0                 10  2018-05-13T06:01:02.000-07:00        TN
# 2             0                  3  2018-05-13T07:55:04.000-07:00        CA
#
#   addrZip  allUtil  annualInc  annualIncJoint applicationType  avgCurBal  \
# 0   488xx     64.6      57200             NaN      INDIVIDUAL       3337
# 1   379xx     23.3      60000             NaN      INDIVIDUAL        334
# 2   951xx     48.5     240000             NaN      INDIVIDUAL       3586
#
#        ...        totCollAmt  totCurBal  totHiCredLim  totalAcc  \
# 0      ...                 0      10010         15500         7
# 1      ...                 0       3677         15800        15
# 2      ...                 0      50208        103461        21
#
#   totalBalExMort  totalBalIl  totalBcLimit  totalCuTl totalIlHighCreditLimit  \
# ...

# %% [markdown]
# #### Summary

# %%
url = 'https://api.lendingclub.com/api/investor/v1/accounts/149011901/summary'
r = requests.get(url, headers=headers)
r.json()
# Out:
# {'accountTotal': 1000,
#  'accruedInterest': 0,
#  'adjustments': {'adjustmentForPastDueNotes': 0,
#   'userAdjustmentForPastDueNotes': None},
#  'availableCash': 975,
#  'infundingBalance': 25,
#  'investorId': 149011901,
#  'netAnnualizedReturn': {'combinedAdjustedNAR': None,
#   'combinedNAR': None,
#   'combinedUserAdjustedNAR': None,
#   'primaryAdjustedNAR': None,
#   'primaryNAR': None,
#   'primaryUserAdjustedNAR': None,
#   'tradedAdjustedNAR': None,
#   'tradedNAR': None,
#   'tradedUserAdjustedNAR': None},
#  'outstandingPrincipal': 0,
#  'receivedInterest': 0,
#  'receivedLateFees': 0,
#  'receivedPrincipal': 0,
#  'totalNotes': 1,
#  'totalPortfolios': 1}

# %% [markdown]
# #### Available Cash

# %%
url = 'https://api.lendingclub.com/api/investor/v1/accounts/149011901/availablecash'
r = requests.get(url, headers=headers)
r.json()
# Out:
# {'availableCash': 975, 'investorId': 149011901}

# %%
r.json()
# Out:
# {'availableCash': 975, 'investorId': 149011901}

# %% [markdown]
# #### Transfer Funds

# %%
url = 'https://api.lendingclub.com/api/investor/v1/accounts/149011901/funds/add'
requests.post(url, headers=headers)
# Out:
# <Response [500]>
